# %% [markdown]
# # Dengue prediction of Dhaka, Bangladesh

# %% [markdown]
# ### Consider weather(temperature, humidity, rainfall)

# %% [markdown]
# ### insert all necessary files and packages

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.multioutput import MultiOutputRegressor
# Out:
# WARNING:tensorflow:From C:\Users\User\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Import dengue cases database(2015 to 2023)

# %%
# Load dataset
df = pd.read_csv('C:/Users/User/anaconda3/Dengue/Database/DengueAndClimateBangladesh.csv')

df.describe()
# Out:
#               YEAR       MONTH         MIN         MAX    HUMIDITY  \
# count   108.000000  108.000000  108.000000  108.000000  108.000000
# mean   2019.000000    6.500000   21.833830   31.047757   79.711230
# std       2.594026    3.468146    4.925797    3.115912    9.747887
# min    2015.000000    1.000000   11.027907   22.987097   48.826452
# 25%    2017.000000    3.750000   18.350682   29.500630   75.216667
# 50%    2019.000000    6.500000   23.830127   31.777857   82.441441
# 75%    2021.000000    9.250000   25.948780   32.900000   87.229597
# max    2023.000000   12.000000   31.063636   39.800000   90.222667
#
#          RAINFALL        DENGUE      DEATHS
# count  108.000000    108.000000  108.000000
# mean   206.932233   5244.648148   22.185185
# std    205.404186  14238.412507   69.020808
# min      0.000000      0.000000    0.000000
# 25%     17.902500     44.500000    0.000000
# 50%    165.789706    320.500000    2.000000
# 75%    319.132353   2316.000000    6.250000
# max    834.735294  79598.000000  396.000000

# %% [markdown]
# ### Split data into features and target

# %%
# data = df.drop('DENGUE', axis=1)
# y = df['DENGUE']
data = df[['YEAR','MONTH','MIN', 'MAX', 'HUMIDITY', 'RAINFALL']]
# y = df['DENGUE']  # Two target variables
y = df[['DENGUE', 'DEATHS']]  # Two target variables

# %%
# # for-2024
# database2024 = pd.read_csv('C:/Users/User/anaconda3/Dengue/Database/2024-database-only.csv')
# data = database2024 [['MIN', 'MAX', 'HUMIDITY', 'RAINFALL']]
# y = database2024[[]]  # Two target variables
# print(data.shape)
# print(y.shape)

# %%
print(data)
print(y)
# Out:
#      YEAR  MONTH        MIN        MAX   HUMIDITY    RAINFALL
# 0    2015      1  13.548485  25.300000  68.976452   10.529000
# 1    2015      2  17.342424  28.712121  56.465000   16.500000
# 2    2015      3  19.669697  31.908824  48.826452   25.823529
# 3    2015      4  23.503030  32.485294  78.554333  192.911765
# 4    2015      5  25.263636  34.111765  85.996129  171.264706
# ..    ...    ...        ...        ...        ...         ...
# 103  2023      8  25.726471  31.373529  86.110000  420.364706
# 104  2023      9  25.355882  31.541176  85.910000  318.220588
# 105  2023     10  23.638235  31.526471  83.200000  160.314706
# 106  2023     11  19.176471  29.529412  79.090000   42.429412
# 107  2023     12  14.170588  26.432353  77.970000    9.638235
#
# [108 rows x 6 columns]
#      DENGUE  DEATHS
# 0         0       0
# 1         0       0
# 2         2       0
# 3         6       0
# 4        10       0
# ..      ...     ...
# 103   71976     342
# 104   79598     396
# 105   67769     359
# 106   40716     274
# 107    9288      83
#
# [108 rows x 2 columns]

# %% [markdown]
# ### Scaling training data using MinMaxScaler (0 to 1)

# %%
X_combined = MinMaxScaler().fit_transform(data)
print(X_combined.shape)
# Out:
# (108, 6)

# %% [markdown]
# ### create input-output pairs (sequences) fo LSTM

# %%
def create_sequences(data, target, sequence_length):
    sequences = []
    target_values = []

    # Combine data and target
    combined_data = pd.concat([pd.DataFrame(data), pd.DataFrame(target)], axis=1)

    # Shift the combined data to create sequences
    for i in range(len(combined_data) - sequence_length + 1):
        sequence_end = i + sequence_length
        if sequence_end > len(combined_data):
            break
        seq = combined_data.iloc[i:sequence_end, :-2].values
        label = combined_data.iloc[sequence_end - 1, -2:].values
        sequences.append(seq)
        target_values.append(label)

    return np.array(sequences), np.array(target_values)

# %% [markdown]
# ### 10 consecutive time steps as input

# %%
# Define the sequence length (number of time steps to look back)
sequence_length = 1

# %% [markdown]
# ### Scaling(range 0 to 1) training data for fit

# %%
# scaler = MinMaxScaler()
# scaler.fit(X_combined)

# %% [markdown]
# ###  Input sequences and target sequnce set with 10 length

# %%
# Create sequences
X_seq, y_seq = create_sequences(np.column_stack((X_combined, y)), y, sequence_length)
print('X_seq:',X_seq.shape)
print('y_seq:',y_seq.shape)
# Out:
# X_seq: (108, 1, 8)
# y_seq: (108, 2)

# %%
y_seq
# Out:
# array([[0.0000e+00, 0.0000e+00],
#        [0.0000e+00, 0.0000e+00],
#        [2.0000e+00, 0.0000e+00],
#        [6.0000e+00, 0.0000e+00],
#        [1.0000e+01, 0.0000e+00],
#        [2.8000e+01, 0.0000e+00],
#        [1.7100e+02, 1.0000e+00],
#        [7.6500e+02, 3.0000e+00],
#        [9.6500e+02, 4.0000e+00],
#        [8.6900e+02, 3.0000e+00],
#        [2.7100e+02, 1.0000e+00],
#        [7.5000e+01, 0.0000e+00],
#        [1.3000e+01, 0.0000e+00],
#        [3.0000e+00, 0.0000e+00],
#        [1.7000e+01, 0.0000e+00],
#        [3.8000e+01, 0.0000e+00],
#        [7.0000e+01, 0.0000e+00],
#        [2.5400e+02, 1.0000e+00],
#        [9.2600e+02, 2.0000e+00],
#        [1.4510e+03, 3.0000e+00],
#        [1.5440e+03, 5.0000e+00],
#        [1.0770e+03, 3.0000e+00],
#        [5.2200e+02, 1.0000e+00],
#        [1.4500e+02, 0.0000e+00],
#        [9.2000e+01, 0.0000e+00],
#        [5.8000e+01, 0.0000e+00],
#        [3.6000e+01, 0.0000e+00],
#        [7.3000e+01, 0.0000e+00],
#        [1.3400e+02, 0.0000e+00],
#        [2.6700e+02, 1.0000e+00],
#        [2.8600e+02, 1.0000e+00],
#        [3.4600e+02, 2.0000e+00],
#        [4.3000e+02, 2.0000e+00],
#        [5.1200e+02, 3.0000e+00],
#        [4.0900e+02, 2.0000e+00],
#        [1.2600e+02, 0.0000e+00],
#        [2.6000e+01, 0.0000e+00],
#        [7.0000e+00, 0.0000e+00],
#        [1.9000e+01, 0.0000e+00],
#        [2.9000e+01, 0.0000e+00],
#        [5.2000e+01, 0.0000e+00],
#        [2.9500e+02, 0.0000e+00],
#        [9.4600e+02, 5.0000e+00],
#        [1.7960e+03, 5.0000e+00],
#        [3.0870e+03, 9.0000e+00],
#        [2.4060e+03, 7.0000e+00],
#        [1.1920e+03, 2.0000e+00],
#        [2.9300e+02, 1.0000e+00],
#        [3.8000e+01, 0.0000e+00],
#        [1.8000e+01, 0.0000e+00],
#        [1.7000e+01, 0.0000e+00],
#        [5.8000e+01, 0.0000e+00],
#        [1.9300e+02, 1.0000e+00],
#        [1.8840e+03, 6.0000e+00],
#        [1.6253e+04, 3.5000e+01],
#        [5.2636e+04, 8.3000e+01],
#        [1.6856e+04, 2.5000e+01],
#        [8.1430e+03, 1.1000e+01],
#        [4.0110e+03, 6.0000e+00],
#        [1.0380e+03, 3.0000e+00],
#        [1.9900e+02, 0.0000e+00],
#        [4.5000e+01, 0.0000e+00],
#        [2.7000e+01, 1.0000e+00],
#        [2.5000e+01, 0.0000e+00],
#        [8.0000e+01, 2.0000e+00],
#        [1.5000e+03, 4.0000e+00],
#        [2.6470e+03, 1.3000e+01],
#        [3.5670e+03, 1.3000e+01],
#        [7.2470e+03, 2.5000e+01],
#        [1.2640e+03, 4.0000e+00],
#        [5.2460e+03, 8.0000e+00],
#        [4.3100e+02, 2.0000e+00],
#        [1.0000e+02, 0.0000e+00],
#        [9.0000e+00, 0.0000e+00],
#        [1.3000e+01, 0.0000e+00],
#        [3.0000e+00, 0.0000e+00],
#        [4.3000e+01, 0.0000e+00],
#        [8.2500e+02, 2.0000e+00],
#        [2.2860e+03, 8.0000e+00],
#        [7.6980e+03, 1.8000e+01],
#        [7.8410e+03, 2.1000e+01],
#        [1.5458e+04, 4.5000e+01],
#        [3.5670e+03, 9.0000e+00],
#        [1.2070e+03, 3.0000e+00],
#        [1.2600e+02, 0.0000e+00],
#        [2.0000e+01, 0.0000e+00],
#        [2.0000e+01, 0.0000e+00],
#        [2.3000e+01, 0.0000e+00],
#        [1.6300e+02, 0.0000e+00],
#        [7.3700e+02, 1.0000e+00],
#        [1.5710e+03, 4.0000e+00],
#        [3.5210e+03, 1.1000e+01],
#        [9.9110e+03, 3.4000e+01],
#        [2.1932e+04, 8.6000e+01],
#        [1.7583e+04, 1.1300e+02],
#        [5.0240e+03, 2.7000e+01],
#        [5.6600e+02, 6.0000e+00],
#        [1.6600e+02, 3.0000e+00],
#        [1.1100e+02, 0.0000e+00],
#        [1.4300e+02, 2.0000e+00],
#        [1.0360e+03, 2.0000e+00],
#        [5.9560e+03, 3.4000e+01],
#        [4.3854e+04, 2.0400e+02],
#        [7.1976e+04, 3.4200e+02],
#        [7.9598e+04, 3.9600e+02],
#        [6.7769e+04, 3.5900e+02],
#        [4.0716e+04, 2.7400e+02],
#        [9.2880e+03, 8.3000e+01]])

# %% [markdown]
# ### Split the data into training and testing sets

# %%
# split = int(0.88 * len(X_seq))
# x_train, x_test = X_seq[:split, :, :-1], X_seq[split:, :, :-1]
# y_train, y_test = y_seq[:split], y_seq[split:]
x_train, x_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

# %%
print('X_combined:',X_combined.shape)
print('y:',y.shape)
print('X_seq:',X_seq.shape)
print('y_seq:',y_seq.shape)
print('x_train:',x_train.shape)
print('y_train:',y_train.shape)
print('x_test:',x_test.shape)
print('y_test:',y_test.shape)
# Out:
# X_combined: (108, 6)
# y: (108, 2)
# X_seq: (108, 1, 8)
# y_seq: (108, 2)
# x_train: (86, 1, 8)
# y_train: (86, 2)
# x_test: (22, 1, 8)
# y_test: (22, 2)

# %% [markdown]
# ### Build the LSTM model

# %%
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(x_train.shape[1], x_train.shape[2])))#, return_sequences=True
model.add(Dense(2))  # Two output nodes for two target variables
model.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:From C:\Users\User\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\User\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# #### Define a function to checkpoint all epochs

# %%
# Define this checkpoint callback methods for draw graph of RMSE of all epoach
checkpoint_callback = ModelCheckpoint(
    filepath='weights_epoch_{epoch:02d}.h5', 
    save_weights_only=True,
    save_best_only=False,  
    monitor='val_loss', 
    mode='min',
    verbose=1
)

# %% [markdown]
# ### Train the model with validation

# %%
pochs=100
history = model.fit(x_train, y_train, epochs=pochs, batch_size=30, 
                    validation_data=(x_test, y_test), 
                    callbacks=[checkpoint_callback],  
                    verbose=2)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\User\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
#
# Epoch 1: saving model to weights_epoch_01.h5
# 3/3 - 2s - loss: 122700992.0000 - val_loss: 50219328.0000 - 2s/epoch - 521ms/step
# Epoch 2/100
#
# Epoch 2: saving model to weights_epoch_02.h5
# 3/3 - 0s - loss: 121603168.0000 - val_loss: 49727184.0000 - 57ms/epoch - 19ms/step
# Epoch 3/100
#
# Epoch 3: saving model to weights_epoch_03.h5
# 3/3 - 0s - loss: 120219728.0000 - val_loss: 49273924.0000 - 59ms/epoch - 20ms/step
# Epoch 4/100
#
# Epoch 4: saving model to weights_epoch_04.h5
# 3/3 - 0s - loss: 118960664.0000 - val_loss: 47723816.0000 - 48ms/epoch - 16ms/step
# Epoch 5/100
#
# Epoch 5: saving model to weights_epoch_05.h5
# 3/3 - 0s - loss: 115283632.0000 - val_loss: 47254464.0000 - 49ms/epoch - 16ms/step
# Epoch 6/100
#
# Epoch 6: saving model to weights_epoch_06.h5
# 3/3 - 0s - loss: 113209752.0000 - val_loss: 44941328.0000 - 44ms/epoch - 15ms/step
# Epoch 7/100
#
# Epoch 7: saving model to weights_epoch_07.h5
# 3/3 - 0s - loss: 108749800.0000 - val_loss: 44497704.0000 - 43ms/epoch - 14ms/step
# Epoch 8/100
#
# Epoch 8: saving model to weights_epoch_08.h5
# 3/3 - 0s - loss: 107921896.0000 - val_loss: 44078416.0000 - 44ms/epoch - 15ms/step
# Epoch 9/100
#
# Epoch 9: saving model to weights_epoch_09.h5
# 3/3 - 0s - loss: 106701096.0000 - val_loss: 43674228.0000 - 49ms/epoch - 16ms/step
# Epoch 10/100
#
# Epoch 10: saving model to weights_epoch_10.h5
# 3/3 - 0s - loss: 105794192.0000 - val_loss: 43253888.0000 - 41ms/epoch - 14ms/step
# Epoch 11/100
#
# Epoch 11: saving model to weights_epoch_11.h5
# 3/3 - 0s - loss: 104787328.0000 - val_loss: 42829056.0000 - 43ms/epoch - 14ms/step
# Epoch 12/100
#
# Epoch 12: saving model to weights_epoch_12.h5
# 3/3 - 0s - loss: 103851128.0000 - val_loss: 42400756.0000 - 44ms/epoch - 15ms/step
# Epoch 13/100
#
# Epoch 13: saving model to weights_epoch_13.h5
# 3/3 - 0s - loss: 102509952.0000 - val_loss: 41995312.0000 - 43ms/epoch - 14ms/step
# Epoch 14/100
#
# Epoch 14: saving model to weights_epoch_14.h5
# 3/3 - 0s - loss: 101658912.0000 - val_loss: 41584640.0000 - 41ms/epoch - 14ms/step
# Epoch 15/100
#
# Epoch 15: saving model to weights_epoch_15.h5
# 3/3 - 0s - loss: 100692360.0000 - val_loss: 41162044.0000 - 43ms/epoch - 14ms/step
# Epoch 16/100
#
# Epoch 16: saving model to weights_epoch_16.h5
# 3/3 - 0s - loss: 99012496.0000 - val_loss: 40370220.0000 - 43ms/epoch - 14ms/step
# Epoch 17/100
#
# Epoch 17: saving model to weights_epoch_17.h5
# 3/3 - 0s - loss: 97736056.0000 - val_loss: 39962008.0000 - 43ms/epoch - 14ms/step
# Epoch 18/100
#
# Epoch 18: saving model to weights_epoch_18.h5
# 3/3 - 0s - loss: 96949008.0000 - val_loss: 39541956.0000 - 42ms/epoch - 14ms/step
# Epoch 19/100
#
# Epoch 19: saving model to weights_epoch_19.h5
# 3/3 - 0s - loss: 95718464.0000 - val_loss: 39140512.0000 - 44ms/epoch - 15ms/step
# Epoch 20/100
#
# Epoch 20: saving model to weights_epoch_20.h5
# 3/3 - 0s - loss: 94715616.0000 - val_loss: 38742104.0000 - 41ms/epoch - 14ms/step
# Epoch 21/100
#
# Epoch 21: saving model to weights_epoch_21.h5
# 3/3 - 0s - loss: 93719840.0000 - val_loss: 38346052.0000 - 44ms/epoch - 15ms/step
# Epoch 22/100
#
# Epoch 22: saving model to weights_epoch_22.h5
# 3/3 - 0s - loss: 92681040.0000 - val_loss: 37947996.0000 - 42ms/epoch - 14ms/step
# Epoch 23/100
#
# Epoch 23: saving model to weights_epoch_23.h5
# 3/3 - 0s - loss: 91629648.0000 - val_loss: 37546700.0000 - 42ms/epoch - 14ms/step
# Epoch 24/100
#
# Epoch 24: saving model to weights_epoch_24.h5
# 3/3 - 0s - loss: 90843568.0000 - val_loss: 37110044.0000 - 43ms/epoch - 14ms/step
# Epoch 25/100
#
# Epoch 25: saving model to weights_epoch_25.h5
# 3/3 - 0s - loss: 89861896.0000 - val_loss: 36661588.0000 - 42ms/epoch - 14ms/step
# Epoch 26/100
#
# Epoch 26: saving model to weights_epoch_26.h5
# 3/3 - 0s - loss: 88761216.0000 - val_loss: 34261588.0000 - 59ms/epoch - 20ms/step
# Epoch 27/100
#
# Epoch 27: saving model to weights_epoch_27.h5
# 3/3 - 0s - loss: 82773848.0000 - val_loss: 33560564.0000 - 45ms/epoch - 15ms/step
# Epoch 28/100
#
# Epoch 28: saving model to weights_epoch_28.h5
# 3/3 - 0s - loss: 74027072.0000 - val_loss: 26524690.0000 - 46ms/epoch - 15ms/step
# Epoch 29/100
#
# Epoch 29: saving model to weights_epoch_29.h5
# 3/3 - 0s - loss: 54335680.0000 - val_loss: 19233364.0000 - 45ms/epoch - 15ms/step
# Epoch 30/100
#
# Epoch 30: saving model to weights_epoch_30.h5
# 3/3 - 0s - loss: 45935284.0000 - val_loss: 18324662.0000 - 44ms/epoch - 15ms/step
# Epoch 31/100
#
# Epoch 31: saving model to weights_epoch_31.h5
# 3/3 - 0s - loss: 43820628.0000 - val_loss: 17365590.0000 - 43ms/epoch - 14ms/step
# Epoch 32/100
#
# Epoch 32: saving model to weights_epoch_32.h5
# 3/3 - 0s - loss: 41275012.0000 - val_loss: 16404922.0000 - 43ms/epoch - 14ms/step
# Epoch 33/100
#
# Epoch 33: saving model to weights_epoch_33.h5
# 3/3 - 0s - loss: 34114604.0000 - val_loss: 11726686.0000 - 42ms/epoch - 14ms/step
# Epoch 34/100
#
# Epoch 34: saving model to weights_epoch_34.h5
# 3/3 - 0s - loss: 23598606.0000 - val_loss: 5340083.0000 - 41ms/epoch - 14ms/step
# Epoch 35/100
#
# Epoch 35: saving model to weights_epoch_35.h5
# 3/3 - 0s - loss: 12531426.0000 - val_loss: 4571569.0000 - 39ms/epoch - 13ms/step
# Epoch 36/100
#
# Epoch 36: saving model to weights_epoch_36.h5
# 3/3 - 0s - loss: 6592522.5000 - val_loss: 569823.2500 - 41ms/epoch - 14ms/step
# Epoch 37/100
#
# Epoch 37: saving model to weights_epoch_37.h5
# 3/3 - 0s - loss: 1368018.8750 - val_loss: 497556.5000 - 43ms/epoch - 14ms/step
# Epoch 38/100
#
# Epoch 38: saving model to weights_epoch_38.h5
# 3/3 - 0s - loss: 1085918.3750 - val_loss: 377209.1875 - 42ms/epoch - 14ms/step
# Epoch 39/100
#
# Epoch 39: saving model to weights_epoch_39.h5
# 3/3 - 0s - loss: 863411.3750 - val_loss: 247688.7500 - 43ms/epoch - 14ms/step
# Epoch 40/100
#
# Epoch 40: saving model to weights_epoch_40.h5
# 3/3 - 0s - loss: 511864.2812 - val_loss: 149188.9062 - 42ms/epoch - 14ms/step
# Epoch 41/100
#
# Epoch 41: saving model to weights_epoch_41.h5
# 3/3 - 0s - loss: 281080.4062 - val_loss: 78700.7578 - 44ms/epoch - 15ms/step
# Epoch 42/100
#
# Epoch 42: saving model to weights_epoch_42.h5
# 3/3 - 0s - loss: 129581.6484 - val_loss: 37646.6992 - 43ms/epoch - 14ms/step
# Epoch 43/100
#
# Epoch 43: saving model to weights_epoch_43.h5
# 3/3 - 0s - loss: 63829.7109 - val_loss: 19063.3516 - 43ms/epoch - 14ms/step
# Epoch 44/100
#
# Epoch 44: saving model to weights_epoch_44.h5
# 3/3 - 0s - loss: 39269.0625 - val_loss: 15449.8838 - 50ms/epoch - 17ms/step
# Epoch 45/100
#
# Epoch 45: saving model to weights_epoch_45.h5
# 3/3 - 0s - loss: 39074.4648 - val_loss: 17884.4766 - 43ms/epoch - 14ms/step
# Epoch 46/100
#
# Epoch 46: saving model to weights_epoch_46.h5
# 3/3 - 0s - loss: 47955.9609 - val_loss: 20176.3418 - 41ms/epoch - 14ms/step
# Epoch 47/100
#
# Epoch 47: saving model to weights_epoch_47.h5
# 3/3 - 0s - loss: 52463.1523 - val_loss: 19488.2031 - 44ms/epoch - 15ms/step
# Epoch 48/100
#
# Epoch 48: saving model to weights_epoch_48.h5
# 3/3 - 0s - loss: 49168.6289 - val_loss: 15992.3867 - 46ms/epoch - 15ms/step
# Epoch 49/100
#
# Epoch 49: saving model to weights_epoch_49.h5
# 3/3 - 0s - loss: 40401.2969 - val_loss: 10419.3779 - 42ms/epoch - 14ms/step
# Epoch 50/100
#
# Epoch 50: saving model to weights_epoch_50.h5
# 3/3 - 0s - loss: 25205.1738 - val_loss: 5710.8315 - 42ms/epoch - 14ms/step
# Epoch 51/100
#
# Epoch 51: saving model to weights_epoch_51.h5
# 3/3 - 0s - loss: 11956.9697 - val_loss: 2580.8401 - 41ms/epoch - 14ms/step
# Epoch 52/100
#
# Epoch 52: saving model to weights_epoch_52.h5
# 3/3 - 0s - loss: 5786.7231 - val_loss: 825.5538 - 44ms/epoch - 15ms/step
# Epoch 53/100
#
# Epoch 53: saving model to weights_epoch_53.h5
# 3/3 - 0s - loss: 2064.0496 - val_loss: 402.7046 - 57ms/epoch - 19ms/step
# Epoch 54/100
#
# Epoch 54: saving model to weights_epoch_54.h5
# 3/3 - 0s - loss: 767.3140 - val_loss: 760.6241 - 44ms/epoch - 15ms/step
# Epoch 55/100
#
# Epoch 55: saving model to weights_epoch_55.h5
# 3/3 - 0s - loss: 1467.5016 - val_loss: 1333.8337 - 43ms/epoch - 14ms/step
# Epoch 56/100
#
# Epoch 56: saving model to weights_epoch_56.h5
# 3/3 - 0s - loss: 2191.0913 - val_loss: 1692.9579 - 42ms/epoch - 14ms/step
# Epoch 57/100
#
# Epoch 57: saving model to weights_epoch_57.h5
# 3/3 - 0s - loss: 2683.5203 - val_loss: 1728.3508 - 43ms/epoch - 14ms/step
# Epoch 58/100
#
# Epoch 58: saving model to weights_epoch_58.h5
# 3/3 - 0s - loss: 2627.6597 - val_loss: 1487.2117 - 43ms/epoch - 14ms/step
# Epoch 59/100
#
# Epoch 59: saving model to weights_epoch_59.h5
# 3/3 - 0s - loss: 2046.5205 - val_loss: 1172.5151 - 46ms/epoch - 15ms/step
# Epoch 60/100
#
# Epoch 60: saving model to weights_epoch_60.h5
# 3/3 - 0s - loss: 1388.5238 - val_loss: 832.4740 - 43ms/epoch - 14ms/step
# Epoch 61/100
#
# Epoch 61: saving model to weights_epoch_61.h5
# 3/3 - 0s - loss: 785.7807 - val_loss: 565.7040 - 41ms/epoch - 14ms/step
# Epoch 62/100
#
# Epoch 62: saving model to weights_epoch_62.h5
# 3/3 - 0s - loss: 373.2717 - val_loss: 397.8668 - 44ms/epoch - 15ms/step
# Epoch 63/100
#
# Epoch 63: saving model to weights_epoch_63.h5
# 3/3 - 0s - loss: 280.7089 - val_loss: 305.6179 - 42ms/epoch - 14ms/step
# Epoch 64/100
#
# Epoch 64: saving model to weights_epoch_64.h5
# 3/3 - 0s - loss: 272.3322 - val_loss: 271.4911 - 41ms/epoch - 14ms/step
# Epoch 65/100
#
# Epoch 65: saving model to weights_epoch_65.h5
# 3/3 - 0s - loss: 284.5762 - val_loss: 265.5368 - 44ms/epoch - 15ms/step
# Epoch 66/100
#
# Epoch 66: saving model to weights_epoch_66.h5
# 3/3 - 0s - loss: 351.0653 - val_loss: 265.3268 - 42ms/epoch - 14ms/step
# Epoch 67/100
#
# Epoch 67: saving model to weights_epoch_67.h5
# 3/3 - 0s - loss: 360.9931 - val_loss: 265.7565 - 41ms/epoch - 14ms/step
# Epoch 68/100
#
# Epoch 68: saving model to weights_epoch_68.h5
# 3/3 - 0s - loss: 338.4625 - val_loss: 267.9254 - 43ms/epoch - 14ms/step
# Epoch 69/100
#
# Epoch 69: saving model to weights_epoch_69.h5
# 3/3 - 0s - loss: 301.1007 - val_loss: 272.4174 - 43ms/epoch - 14ms/step
# Epoch 70/100
#
# Epoch 70: saving model to weights_epoch_70.h5
# 3/3 - 0s - loss: 284.2399 - val_loss: 285.3123 - 42ms/epoch - 14ms/step
# Epoch 71/100
#
# Epoch 71: saving model to weights_epoch_71.h5
# 3/3 - 0s - loss: 247.5368 - val_loss: 299.5954 - 42ms/epoch - 14ms/step
# Epoch 72/100
#
# Epoch 72: saving model to weights_epoch_72.h5
# 3/3 - 0s - loss: 241.2688 - val_loss: 314.9966 - 42ms/epoch - 14ms/step
# Epoch 73/100
#
# Epoch 73: saving model to weights_epoch_73.h5
# 3/3 - 0s - loss: 241.7016 - val_loss: 328.3320 - 44ms/epoch - 15ms/step
# Epoch 74/100
#
# Epoch 74: saving model to weights_epoch_74.h5
# 3/3 - 0s - loss: 240.5502 - val_loss: 335.2183 - 45ms/epoch - 15ms/step
# Epoch 75/100
#
# Epoch 75: saving model to weights_epoch_75.h5
# 3/3 - 0s - loss: 240.8662 - val_loss: 333.8679 - 42ms/epoch - 14ms/step
# Epoch 76/100
#
# Epoch 76: saving model to weights_epoch_76.h5
# 3/3 - 0s - loss: 239.1800 - val_loss: 330.5645 - 44ms/epoch - 15ms/step
# Epoch 77/100
#
# Epoch 77: saving model to weights_epoch_77.h5
# 3/3 - 0s - loss: 240.0210 - val_loss: 322.1951 - 49ms/epoch - 16ms/step
# Epoch 78/100
#
# Epoch 78: saving model to weights_epoch_78.h5
# 3/3 - 0s - loss: 235.7403 - val_loss: 319.3384 - 43ms/epoch - 14ms/step
# Epoch 79/100
#
# Epoch 79: saving model to weights_epoch_79.h5
# 3/3 - 0s - loss: 235.4276 - val_loss: 310.6879 - 41ms/epoch - 14ms/step
# Epoch 80/100
#
# Epoch 80: saving model to weights_epoch_80.h5
# 3/3 - 0s - loss: 232.5013 - val_loss: 307.5628 - 43ms/epoch - 14ms/step
# Epoch 81/100
#
# Epoch 81: saving model to weights_epoch_81.h5
# 3/3 - 0s - loss: 232.5945 - val_loss: 302.7957 - 45ms/epoch - 15ms/step
# Epoch 82/100
#
# Epoch 82: saving model to weights_epoch_82.h5
# 3/3 - 0s - loss: 231.3287 - val_loss: 301.0669 - 43ms/epoch - 14ms/step
# Epoch 83/100
#
# Epoch 83: saving model to weights_epoch_83.h5
# 3/3 - 0s - loss: 232.0307 - val_loss: 300.8026 - 43ms/epoch - 14ms/step
# Epoch 84/100
#
# Epoch 84: saving model to weights_epoch_84.h5
# 3/3 - 0s - loss: 233.4647 - val_loss: 297.5746 - 45ms/epoch - 15ms/step
# Epoch 85/100
#
# Epoch 85: saving model to weights_epoch_85.h5
# 3/3 - 0s - loss: 231.4569 - val_loss: 300.1821 - 43ms/epoch - 14ms/step
# Epoch 86/100
#
# Epoch 86: saving model to weights_epoch_86.h5
# 3/3 - 0s - loss: 230.9755 - val_loss: 303.2225 - 42ms/epoch - 14ms/step
# Epoch 87/100
#
# Epoch 87: saving model to weights_epoch_87.h5
# 3/3 - 0s - loss: 230.2311 - val_loss: 305.6495 - 43ms/epoch - 14ms/step
# Epoch 88/100
#
# Epoch 88: saving model to weights_epoch_88.h5
# 3/3 - 0s - loss: 229.6873 - val_loss: 307.2402 - 41ms/epoch - 14ms/step
# Epoch 89/100
#
# Epoch 89: saving model to weights_epoch_89.h5
# 3/3 - 0s - loss: 229.0428 - val_loss: 307.5642 - 41ms/epoch - 14ms/step
# Epoch 90/100
#
# Epoch 90: saving model to weights_epoch_90.h5
# 3/3 - 0s - loss: 230.4973 - val_loss: 305.0531 - 42ms/epoch - 14ms/step
# Epoch 91/100
#
# Epoch 91: saving model to weights_epoch_91.h5
# 3/3 - 0s - loss: 228.6758 - val_loss: 306.4641 - 43ms/epoch - 14ms/step
# Epoch 92/100
#
# Epoch 92: saving model to weights_epoch_92.h5
# 3/3 - 0s - loss: 228.3705 - val_loss: 305.4499 - 42ms/epoch - 14ms/step
# Epoch 93/100
#
# Epoch 93: saving model to weights_epoch_93.h5
# 3/3 - 0s - loss: 228.8615 - val_loss: 307.4245 - 46ms/epoch - 15ms/step
# Epoch 94/100
#
# Epoch 94: saving model to weights_epoch_94.h5
# 3/3 - 0s - loss: 227.4523 - val_loss: 306.6460 - 59ms/epoch - 20ms/step
# Epoch 95/100
#
# Epoch 95: saving model to weights_epoch_95.h5
# 3/3 - 0s - loss: 230.1446 - val_loss: 302.9576 - 45ms/epoch - 15ms/step
# Epoch 96/100
#
# Epoch 96: saving model to weights_epoch_96.h5
# 3/3 - 0s - loss: 228.0219 - val_loss: 301.3590 - 42ms/epoch - 14ms/step
# Epoch 97/100
#
# Epoch 97: saving model to weights_epoch_97.h5
# 3/3 - 0s - loss: 227.3301 - val_loss: 303.6918 - 41ms/epoch - 14ms/step
# Epoch 98/100
#
# Epoch 98: saving model to weights_epoch_98.h5
# 3/3 - 0s - loss: 226.6384 - val_loss: 304.8010 - 43ms/epoch - 14ms/step
# Epoch 99/100
#
# Epoch 99: saving model to weights_epoch_99.h5
# 3/3 - 0s - loss: 226.7714 - val_loss: 302.9984 - 42ms/epoch - 14ms/step
# Epoch 100/100
#
# Epoch 100: saving model to weights_epoch_100.h5
# 3/3 - 0s - loss: 225.7326 - val_loss: 303.5735 - 42ms/epoch - 14ms/step

# %% [markdown]
# #### store all  RMSE value of each Epoch

# %%
predictions = model.predict(x_test)
# predictions abs(predictions)
print(x_test.shape)
print(predictions.shape)
print(y_test.shape)
print(predictions)
print(y_test)
pp=predictions
# Out:
# 1/1 [==============================] - 0s 184ms/step
# (22, 1, 8)
# (22, 2)
# (22, 2)
# [[8.2879236e+02 3.2555795e+00]
#  [2.7026474e+02 3.5906839e-01]
#  [9.7809048e+00 8.8760868e-02]
#  [1.2092220e+03 4.8510919e+00]
#  [2.4296951e+01 3.3109283e-01]
#  [3.5697048e+03 1.5544742e+01]
#  [2.8884464e+02 4.5175791e-01]
#  [2.4077913e+03 1.0334506e+01]
#  [5.0282847e+03 2.2090670e+01]
#  [6.8949928e+01 1.1238036e+00]
#  [1.5452347e+04 6.8836639e+01]
#  [7.6955547e+03 3.3992344e+01]
#  [3.5295159e-01 1.0824896e-02]
#  [7.8392407e+03 3.4654881e+01]
#  [9.2887622e+02 3.7451882e+00]
#  [1.2672196e+03 5.1623559e+00]
#  [1.6839965e+04 7.4916840e+01]
#  [4.1814404e+01 1.1214485e+00]
#  [4.0749551e+04 1.8338876e+02]
#  [9.5004907e+02 3.8337808e+00]
#  [9.9745245e+00 1.4541283e-02]
#  [2.1744226e+01 4.1390300e-01]]
# [[8.2500e+02 2.0000e+00]
#  [2.7100e+02 1.0000e+00]
#  [1.0000e+01 0.0000e+00]
#  [1.2070e+03 3.0000e+00]
#  [2.7000e+01 1.0000e+00]
#  [3.5670e+03 1.3000e+01]
#  [2.8600e+02 1.0000e+00]
#  [2.4060e+03 7.0000e+00]
#  [5.0240e+03 2.7000e+01]
#  [7.5000e+01 0.0000e+00]
#  [1.5458e+04 4.5000e+01]
#  [7.6980e+03 1.8000e+01]
#  [0.0000e+00 0.0000e+00]
#  [7.8410e+03 2.1000e+01]
#  [9.2600e+02 2.0000e+00]
#  [1.2640e+03 4.0000e+00]
#  [1.6856e+04 2.5000e+01]
#  [4.3000e+01 0.0000e+00]
#  [4.0716e+04 2.7400e+02]
#  [9.4600e+02 5.0000e+00]
#  [1.3000e+01 0.0000e+00]
#  [2.6000e+01 0.0000e+00]]

# %%
# store all RMSE values for each epoch
rmse_values_affected = []
rmse_values_deaths = []

for epoch in range(1, pochs+1):
    
    model.load_weights(f"weights_epoch_{epoch:02d}.h5")

    # Predictions on the test set
    predictions = model.predict(x_test)

    # Calculate RMSE for dengue affected case
#     mse = mean_squared_error(y_test, predictions)
    mse = mean_squared_error(y_test[:, 0], predictions[:, 0])
    rmse = np.sqrt(mse)
    # Append RMSE to the list
    rmse_values_affected.append(rmse)
    
    # rmse for deaths
    mse = mean_squared_error(y_test[:, 1], predictions[:, 1])
    rmse = np.sqrt(mse)
    # Append RMSE to the list
    rmse_values_deaths.append(rmse)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 10ms/step

# %% [markdown]
# #### Draw RMSE vs Epochs

# %%
# Plot RMSE values for affected
plt.plot(range(1, pochs+1), rmse_values_affected, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Root Mean Squared Error (RMSE)')
plt.title('RMSE vs Epochs')
plt.show()

# %%
# Plot RMSE values for deaths
plt.plot(range(1, pochs+1), rmse_values_deaths, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Root Mean Squared Error (RMSE)')
plt.title('RMSE vs Epochs')
plt.show()

# %% [markdown]
# ### Predictions on the test set

# %%
# predictions = model.predict(x_test)

# %%
#print the prediction information
predictions
# Out:
# array([[8.2879236e+02, 3.2555795e+00],
#        [2.7026474e+02, 3.5906839e-01],
#        [9.7809048e+00, 8.8760868e-02],
#        [1.2092220e+03, 4.8510919e+00],
#        [2.4296951e+01, 3.3109283e-01],
#        [3.5697048e+03, 1.5544742e+01],
#        [2.8884464e+02, 4.5175791e-01],
#        [2.4077913e+03, 1.0334506e+01],
#        [5.0282847e+03, 2.2090670e+01],
#        [6.8949928e+01, 1.1238036e+00],
#        [1.5452347e+04, 6.8836639e+01],
#        [7.6955547e+03, 3.3992344e+01],
#        [3.5295159e-01, 1.0824896e-02],
#        [7.8392407e+03, 3.4654881e+01],
#        [9.2887622e+02, 3.7451882e+00],
#        [1.2672196e+03, 5.1623559e+00],
#        [1.6839965e+04, 7.4916840e+01],
#        [4.1814404e+01, 1.1214485e+00],
#        [4.0749551e+04, 1.8338876e+02],
#        [9.5004907e+02, 3.8337808e+00],
#        [9.9745245e+00, 1.4541283e-02],
#        [2.1744226e+01, 4.1390300e-01]], dtype=float32)

# %%
predictions = model.predict(x_test)
predictions= abs(predictions)
predictions
# Out:
# 1/1 [==============================] - 0s 22ms/step
# array([[8.2879236e+02, 3.2555795e+00],
#        [2.7026474e+02, 3.5906839e-01],
#        [9.7809048e+00, 8.8760868e-02],
#        [1.2092220e+03, 4.8510919e+00],
#        [2.4296951e+01, 3.3109283e-01],
#        [3.5697048e+03, 1.5544742e+01],
#        [2.8884464e+02, 4.5175791e-01],
#        [2.4077913e+03, 1.0334506e+01],
#        [5.0282847e+03, 2.2090670e+01],
#        [6.8949928e+01, 1.1238036e+00],
#        [1.5452347e+04, 6.8836639e+01],
#        [7.6955547e+03, 3.3992344e+01],
#        [3.5295159e-01, 1.0824896e-02],
#        [7.8392407e+03, 3.4654881e+01],
#        [9.2887622e+02, 3.7451882e+00],
#        [1.2672196e+03, 5.1623559e+00],
#        [1.6839965e+04, 7.4916840e+01],
#        [4.1814404e+01, 1.1214485e+00],
#        [4.0749551e+04, 1.8338876e+02],
#        [9.5004907e+02, 3.8337808e+00],
#        [9.9745245e+00, 1.4541283e-02],
#        [2.1744226e+01, 4.1390300e-01]], dtype=float32)

# %%
rSquired = r2_score(y_test[:, 0], predictions[:, 0])
print(f'R-squared: {rSquired}')
# Out:
# R-squared: 0.9999991391682738

# %%
r2 = r2_score(y_test[:, 1], predictions[:, 1])
print(f'R-squared: {r2}')
# Out:
# R-squared: 0.8326758378734952

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (86, 1, 8)
# (86, 2)
# (22, 1, 8)
# (22, 2)

# %%
print(predictions.shape)
print(y_test.shape)
# Out:
# (22, 2)
# (22, 2)

# %%
print(y_test)
print(predictions)

print(type(y_test))
print(type(predictions))
# Out:
# [[8.2500e+02 2.0000e+00]
#  [2.7100e+02 1.0000e+00]
#  [1.0000e+01 0.0000e+00]
#  [1.2070e+03 3.0000e+00]
#  [2.7000e+01 1.0000e+00]
#  [3.5670e+03 1.3000e+01]
#  [2.8600e+02 1.0000e+00]
#  [2.4060e+03 7.0000e+00]
#  [5.0240e+03 2.7000e+01]
#  [7.5000e+01 0.0000e+00]
#  [1.5458e+04 4.5000e+01]
#  [7.6980e+03 1.8000e+01]
#  [0.0000e+00 0.0000e+00]
#  [7.8410e+03 2.1000e+01]
#  [9.2600e+02 2.0000e+00]
#  [1.2640e+03 4.0000e+00]
#  [1.6856e+04 2.5000e+01]
#  [4.3000e+01 0.0000e+00]
#  [4.0716e+04 2.7400e+02]
#  [9.4600e+02 5.0000e+00]
#  [1.3000e+01 0.0000e+00]
#  [2.6000e+01 0.0000e+00]]
# [[8.2879236e+02 3.2555795e+00]
#  [2.7026474e+02 3.5906839e-01]
#  [9.7809048e+00 8.8760868e-02]
#  [1.2092220e+03 4.8510919e+00]
#  [2.4296951e+01 3.3109283e-01]
#  [3.5697048e+03 1.5544742e+01]
#  [2.8884464e+02 4.5175791e-01]
#  [2.4077913e+03 1.0334506e+01]
#  [5.0282847e+03 2.2090670e+01]
#  [6.8949928e+01 1.1238036e+00]
#  [1.5452347e+04 6.8836639e+01]
#  [7.6955547e+03 3.3992344e+01]
#  [3.5295159e-01 1.0824896e-02]
#  [7.8392407e+03 3.4654881e+01]
#  [9.2887622e+02 3.7451882e+00]
#  [1.2672196e+03 5.1623559e+00]
#  [1.6839965e+04 7.4916840e+01]
#  [4.1814404e+01 1.1214485e+00]
#  [4.0749551e+04 1.8338876e+02]
#  [9.5004907e+02 3.8337808e+00]
#  [9.9745245e+00 1.4541283e-02]
#  [2.1744226e+01 4.1390300e-01]]
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Performance mesure

# %% [markdown]
# ### Designed a bar graph of actual dengue case VS predictive dengue case

# %%
print(y_test.shape)
print(predictions.shape)
# Out:
# (22, 2)
# (22, 2)

# %% [markdown]
# ####### Loop through each sample
# for i in range(len(y_test)):
#     print(f"Sample {i + 1}:")
#
#     # Loop through each time step
#     for j in range(len(y_test[i])):
#         actual_affected = y_test[i][j][0]
#         actual_death = y_test[i][j][1]
#
#         predicted_affected = predictions[i][j][0]
#         predicted_death = predictions[i][j][1]
#
#         print(f"Time Step {j + 1}:")
#         print(f"  Predicted Affected Cases: {predicted_affected}")
#         print(f"  Actual Affected Cases: {actual_affected}")
#         print(f"  Predicted Death Cases: {predicted_death}")
#         print(f"  Actual Death Cases: {actual_death}")

# %%
# Plot the bar graph for affected dengue cases
plt.figure(figsize=(12, 6))
bar_width = 0.35
plt.subplot(2, 1, 1)  # 2 rows, 1 column, 1st subplot

# Extract the first column of y_test (affected cases) for plotting
affected_actual = y_test[:, 0]  # Selecting the first column
affected_predicted = predictions[:, 0]  # Predicted affected cases

plt.bar(np.arange(len(affected_actual)), affected_actual, width=bar_width, label='Actual Affected Cases')
plt.bar(np.arange(len(affected_predicted)) + bar_width, affected_predicted, width=bar_width, label='Predicted Affected Cases')

plt.xlabel('Data Points')
plt.ylabel('Affected Dengue Cases')
plt.legend()
plt.title('Affected Dengue Cases: Actual vs Predictions')
plt.ylim(0, max(max(affected_actual), max(predictions[:, 0])) * 1.1)  # Set y-axis limit

plt.subplot(2, 1, 2)  # 2 rows, 1 column, 2nd subplot
# Extract the actual and predicted death dengue cases
death_actual = y_test[:, 1]  # Actual death cases
death_predicted = predictions[:, 1]  # Predicted death cases
plt.bar(np.arange(len(death_actual)), death_actual, width=bar_width, label='Actual Death Cases')
plt.bar(np.arange(len(death_predicted)) + bar_width, death_predicted, width=bar_width, label='Predicted Death Cases')
plt.xlabel('Data Points')
plt.ylabel('Dengue Cases')
plt.legend()
plt.title('Death Dengue Cases: Actual vs Predictions')
plt.ylim(0, max(max(death_actual), max(predictions[:, 1])) * 1.1)  # Set y-axis limit

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %% [markdown]
# ###  Designed a graph of training loss and validation loss in times of dataset passing in the model.

# %%
# Plot training and validation loss
plt.figure(figsize=(12, 3))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### R-squared (R²) ,0 to 1;  higher values indicating a better fit

# %%
# Compute R-squared
r2 = r2_score(y_test, predictions)

print(f'R-squared: {r2}')
# Out:
# R-squared: 0.9163374885208845

# %% [markdown]
# ##  RMSE VS Baseline of RMSE

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(y_test, predictions)

# Calculate Root Mean Squared Error
rmse = np.sqrt(mse)
mean_baseline_predictions = np.full_like(y_test, np.mean(y_test))

# Calculate RMSE Mean Baseline
rmse_mean_baseline = np.sqrt(mean_squared_error(y_test, mean_baseline_predictions))

print('Mean Squared Error (RMSE):',mse)
print('Root Mean Squared Error (RMSE)',rmse)
print(f'Mean Baseline RMSE: {rmse_mean_baseline}')
# Out:
# Mean Squared Error (RMSE): 303.57354039614216
# Root Mean Squared Error (RMSE) 17.423361914284573
# Mean Baseline RMSE: 6901.986296179139

# %%
# bar difference more then better model
plt.figure(figsize=(3, 3))
plt.bar(['RMSE', 'Mean Baseline'], [rmse, rmse_mean_baseline], color=['blue', 'orange'], width=0.5)
plt.xlabel('Comparison')
plt.ylabel('Root Mean Squared Error (RMSE)')
plt.title('Comparison of Model RMSE vs Mean Baseline RMSE')
plt.show()

# %% [markdown]
# ## Dengue predict by other moedels

# %%
print(data)
print(y)
# Out:
#      YEAR  MONTH        MIN        MAX   HUMIDITY    RAINFALL
# 0    2015      1  13.548485  25.300000  68.976452   10.529000
# 1    2015      2  17.342424  28.712121  56.465000   16.500000
# 2    2015      3  19.669697  31.908824  48.826452   25.823529
# 3    2015      4  23.503030  32.485294  78.554333  192.911765
# 4    2015      5  25.263636  34.111765  85.996129  171.264706
# ..    ...    ...        ...        ...        ...         ...
# 103  2023      8  25.726471  31.373529  86.110000  420.364706
# 104  2023      9  25.355882  31.541176  85.910000  318.220588
# 105  2023     10  23.638235  31.526471  83.200000  160.314706
# 106  2023     11  19.176471  29.529412  79.090000   42.429412
# 107  2023     12  14.170588  26.432353  77.970000    9.638235
#
# [108 rows x 6 columns]
#      DENGUE  DEATHS
# 0         0       0
# 1         0       0
# 2         2       0
# 3         6       0
# 4        10       0
# ..      ...     ...
# 103   71976     342
# 104   79598     396
# 105   67769     359
# 106   40716     274
# 107    9288      83
#
# [108 rows x 2 columns]

# %%
print(data.shape)
print(y.shape)

train_x, test_x, train_y, test_y = train_test_split(data, y, test_size=0.2, random_state=42)
print(train_x.shape)
print(test_x.shape)
print(train_y.shape)
print(test_y.shape)
# Out:
# (108, 6)
# (108, 2)
# (86, 6)
# (22, 6)
# (86, 2)
# (22, 2)

# %% [markdown]
# ### Normalization

# %%
min_max_scaler = MinMaxScaler()
train_x = min_max_scaler.fit_transform(train_x)
test_x = min_max_scaler.transform(test_x)

# %% [markdown]
# ### Standardization

# %%
scaler = StandardScaler()
train_x = scaler.fit_transform(train_x)
test_x = scaler.transform(test_x)

# %% [markdown]
# #### Models build

# %%
# KNN model
model_k = KNeighborsClassifier(n_neighbors=3)
model_k.fit(train_x, train_y)
predictions_k = model_k.predict(test_x)
print('shape of x test', x_test.shape)
print(predictions_k)

# SVM model
model_s = SVC(kernel='poly', degree=2, C=2.0, gamma=1)  
multi_output_model = MultiOutputClassifier(model_s)
# Train the model
multi_output_model.fit(train_x, train_y)
# Make predictions
predictions_s = multi_output_model.predict(test_x)
print(predictions_s)

# Gradient Boosting Regressor model
model_g = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
# Wrap the model with MultiOutputRegressor to handle multiple target columns
multi_output_model_g = MultiOutputRegressor(model_g)
multi_output_model_g.fit(train_x, train_y)
predictions_g = multi_output_model_g.predict(test_x)
print(predictions_g)
# Out:
# shape of x test (22, 1, 8)
# [[ 295    0]
#  [ 145    0]
#  [  38    0]
#  [ 431    2]
#  [   9    0]
#  [ 737    1]
#  [  28    0]
#  [ 512    3]
#  [3567    8]
#  [ 126    0]
#  [1571    4]
#  [ 737    1]
#  [  38    0]
#  [3521   11]
#  [  28    0]
#  [8143   11]
#  [1796    5]
#  [  23    0]
#  [3567    8]
#  [ 267    0]
#  [  38    0]
#  [  92    0]]
# [[ 2286     8]
#  [  522     0]
#  [   38     0]
#  [ 9288     8]
#  [   17     0]
#  [ 7247     0]
#  [16253    35]
#  [ 8143    11]
#  [ 9288     8]
#  [  145     1]
#  [  199     0]
#  [  737     0]
#  [   92    34]
#  [   36    11]
#  [   28     1]
#  [   36     0]
#  [52636     0]
#  [  193     0]
#  [17583   113]
#  [  295     2]
#  [   92    34]
#  [  199     0]]
# [[ 9.08012599e+02 -2.70780383e+00]
#  [ 7.15592765e+02  2.30829448e+00]
#  [ 3.33505029e+02 -6.17736507e-02]
#  [ 2.61064180e+03  6.12009206e+00]
#  [ 3.96890506e+02  1.21129314e+01]
#  [ 7.20306272e+03  1.85527195e+01]
#  [ 1.90896600e+03  5.27545758e+00]
#  [ 1.43879095e+03  4.08693691e+00]
#  [ 9.24702555e+03  4.65895740e+01]
#  [ 3.63231529e+02  3.01934542e+00]
#  [ 8.08422112e+03  9.27301081e+00]
#  [ 7.49793948e+03  1.72783402e+01]
#  [-2.82227088e+02 -2.15513822e+00]
#  [ 7.98314233e+03  1.63552430e+01]
#  [-5.20221935e+02  4.58637259e+00]
#  [ 8.04725183e+03  2.52517331e+01]
#  [ 8.20284647e+03  2.18172252e+01]
#  [-4.02429157e+02 -1.35458575e+00]
#  [ 1.74353085e+04  1.49386768e+02]
#  [-4.10203546e+02  3.77904693e+00]
#  [-3.02093932e+02 -4.77241627e-01]
#  [-2.37507056e+02 -8.15713186e-01]]

# %%
# Bar graph using subplots
plt.figure(figsize=(12, 8))

# Affected Dengue Cases subplot
plt.subplot(2, 1, 1)  # 2 rows, 1 column, 1st subplot
bar_width = 0.2
indices = np.arange(len(test_y))
# maxDeath=max(predictions_k[:, 0]),
plt.bar(indices, test_y.to_numpy()[:, 0], width=bar_width, label='Actual Affected Cases')
plt.bar(indices + bar_width, predictions_k[:, 0], width=bar_width, label='KNN Predictions')
plt.bar(indices + 2 * bar_width, predictions_s[:, 0], width=bar_width, label='SVM Predictions')
plt.bar(indices + 3 * bar_width, predictions_g[:, 0], width=bar_width, label='Gradient Boosting Predictions')

plt.xlabel('Data Points')
plt.ylabel('Dengue Cases')
plt.xticks(indices + 1.5 * bar_width, indices + 1)
plt.legend()
plt.title('Affected Dengue Cases: Actual vs Predictions')
plt.ylim(0,)  # Set y-axis limit

# Death Dengue Cases subplot
plt.subplot(2, 1, 2)  # 2 rows, 1 column, 2nd subplot
plt.bar(indices, test_y.to_numpy()[:, 1], width=bar_width, label='Actual Death Cases')
plt.bar(indices + bar_width, predictions_k[:, 1], width=bar_width, label='KNN Predictions')
plt.bar(indices + 2 * bar_width, predictions_s[:, 1], width=bar_width, label='SVM Predictions')
plt.bar(indices + 3 * bar_width, predictions_g[:, 1], width=bar_width, label='Gradient Boosting Predictions')

plt.xlabel('Data Points')
plt.ylabel('Dengue Cases')
plt.xticks(indices + 1.5 * bar_width, indices + 1)
plt.legend()
plt.title('Death Dengue Cases: Actual vs Predictions')
plt.ylim(0,)  # Set y-axis limit

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %%
rmse_lstm = rmse
# rmse_lstm = np.sqrt(mean_squared_error(test_y, pp))
rmse_gb = np.sqrt(mean_squared_error(test_y, predictions_g))
rmse_svm = np.sqrt(mean_squared_error(test_y, predictions_s))
rmse_knn = np.sqrt(mean_squared_error(test_y, predictions_k))

print("LSTM(RMSE):", rmse_lstm)
print("Gradient Boosting Regressor(RMSE):", rmse_gb)
print("SVM(RMSE):", rmse_svm)
print("KNN(RMSE):", rmse_knn)

models = ['LSTM', 'Gradient Boosting', 'SVM', 'KNN']
rmse_values_affected = [rmse_lstm, rmse_gb, rmse_svm, rmse_knn]

plt.bar(models, rmse_values_affected, color=['blue', 'orange', 'green', 'red'])
plt.xlabel('Models')
plt.ylabel('Root Mean Squared Error (RMSE)')
plt.title('Comparison of RMSE for Different Models')
plt.show()
# Out:
# LSTM(RMSE): 17.423361914284573
# Gradient Boosting Regressor(RMSE): 4152.8529982762575
# SVM(RMSE): 7609.027770591744
# KNN(RMSE): 6623.263829110237

# %%
rSquired
# Out:
# 0.9999991391682738

# %% [markdown]
# ## 2024 dengue affected and death case predict

# %%
# Assuming your model is already trained and loaded
# Assuming your model expects input of shape (batch_size, sequence_length, num_features)
# You need to add two additional features to match the expected input shape (10, 8)

# Define the function to create sequences
def create_sequences(data, sequence_length):
    sequences = []
    for i in range(len(data) - sequence_length + 1):
        sequence_end = i + sequence_length
        if sequence_end > len(data):
            break
        seq = data[i:sequence_end]
        sequences.append(seq)
    return np.array(sequences)

# Load the 2024 database
database2024 = pd.read_csv('C:/Users/User/anaconda3/Dengue/Database/2024-database-only.csv')
data = database2024[['YEAR', 'MONTH', 'MIN', 'MAX', 'HUMIDITY', 'RAINFALL']]

# Scale the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(data)

# Define the sequence length
sequence_length = 1

# Create sequences for training/testing
X_seq = create_sequences(X_scaled, sequence_length)
print('X_seq shape:', X_seq.shape)

# Assuming your model is already trained and loaded
# Define a placeholder for the predicted target variables
# below statement modify 2 column output is consider as 2 additional features of below code.
additional_features = np.zeros((X_seq.shape[0], X_seq.shape[1], 2))  # Assuming 2 additional features
dat = df[df['YEAR'] == 2019][['DENGUE', 'DEATHS']]
additional_features[:, :, :] = dat.values.reshape((dat.shape[0], 1, 2))

X_seq_with_additional_features = np.concatenate([X_seq, additional_features], axis=-1)

# Now X_seq_with_additional_features has shape (3, 10, 8)
# Now you can use X_seq_with_additional_features to make predictions
predictions = model.predict(X_seq_with_additional_features)

# Now you have the predictions for the target variables
print('Predictions shape:', predictions.shape)
print('Predictions:', predictions)
# Out:
# X_seq shape: (12, 1, 6)
# 1/1 [==============================] - 0s 34ms/step
# Predictions shape: (12, 2)
# Predictions: [[3.1054672e+01 8.3946419e-01]
#  [1.4579745e+01 2.0189048e-01]
#  [1.4472045e+01 2.4657632e-01]
#  [5.4495174e+01 1.4497666e+00]
#  [1.9442447e+02 4.3496752e-01]
#  [1.8873656e+03 8.1116362e+00]
#  [1.6241989e+04 7.2424408e+01]
#  [5.2579727e+04 2.3506406e+02]
#  [1.6840303e+04 7.4985443e+01]
#  [8.1369585e+03 3.6008152e+01]
#  [4.0090779e+03 1.7532442e+01]
#  [1.0393837e+03 4.2137170e+00]]

# %%
# Months for x-axis (assuming 12 months)
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

# Extracting predicted values for affected and death dengue cases
predicted_affected_cases = [pred[0] for pred in predictions]
predicted_death_cases = [pred[1] for pred in predictions]

# Plotting the bar graph
plt.figure(figsize=(10, 6))
plt.bar(months, predicted_affected_cases, color='blue', alpha=0.7, label='Predicted Affected Cases')
plt.bar(months, predicted_death_cases, color='red', alpha=0.7, label='Predicted Death Cases')
plt.xlabel('Month')
plt.ylabel('Predicted Cases')
plt.title('Predicted Affected and Death Dengue Cases for 2024')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Months for x-axis (assuming 12 months)
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

# Extracting predicted values for affected and death dengue cases
predicted_affected_cases = [pred[0] for pred in predictions]
predicted_death_cases = [pred[1] for pred in predictions]

# Plotting the subplots
fig, axs = plt.subplots(2, 1, figsize=(10, 6))

# Plot for affected cases
axs[0].bar(months, predicted_affected_cases, color='blue', alpha=0.7)
axs[0].set_ylabel('Affected Cases')
axs[0].set_title('Predicted Affected Dengue Cases for 2024')

# Plot for death cases
axs[1].bar(months, predicted_death_cases, color='red', alpha=0.7)
axs[1].set_ylabel('Death Cases')
axs[1].set_title('Predicted Death Dengue Cases for 2024')

# Rotate x-axis labels for better visibility
for ax in axs:
    ax.set_xticklabels(months, rotation=45)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_1940\870624137.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(months, rotation=45)

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('C:/Users/User/anaconda3/Dengue/Database/DengueAndClimateBangladesh.csv')

# Filter the DataFrame for rows where the year is 2019 and select specific columns
dat = df[df['YEAR'] == 2019][['DENGUE', 'DEATHS']]

# Print only the values without column names and index
print(dat.to_string(header=False, index=False))
# Out:
#    38  0
#    18  0
#    17  0
#    58  0
#   193  1
#  1884  6
# 16253 35
# 52636 83
# 16856 25
#  8143 11
#  4011  6
#  1038  3

# %%
additional_features[:, :, :] = dat.values.reshape((dat.shape[0], 1, 2))
additional_features
# Out:
# array([[[3.8000e+01, 0.0000e+00]],
#
#        [[1.8000e+01, 0.0000e+00]],
#
#        [[1.7000e+01, 0.0000e+00]],
#
#        [[5.8000e+01, 0.0000e+00]],
#
#        [[1.9300e+02, 1.0000e+00]],
#
#        [[1.8840e+03, 6.0000e+00]],
#
#        [[1.6253e+04, 3.5000e+01]],
#
#        [[5.2636e+04, 8.3000e+01]],
#
#        [[1.6856e+04, 2.5000e+01]],
#
#        [[8.1430e+03, 1.1000e+01]],
#
#        [[4.0110e+03, 6.0000e+00]],
#
#        [[1.0380e+03, 3.0000e+00]]])

# %%
import matplotlib.pyplot as plt

# Months for x-axis (assuming 12 months)
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

# Extracting predicted values for affected and death dengue cases
predicted_affected_cases = [pred[0] for pred in predictions]
predicted_death_cases = [pred[1] for pred in predictions]

# Plotting the subplots
fig, axs = plt.subplots(3, 1, figsize=(10, 9))

# Plot for combined affected and death cases
axs[0].bar(months, predicted_affected_cases, color='blue', alpha=0.7, label='Affected Cases')
axs[0].bar(months, predicted_death_cases, color='red', alpha=0.7, label='Death Cases')
axs[0].set_ylabel('Predicted Cases')
axs[0].set_title('Predicted Affected and Death Dengue Cases for 2024')
axs[0].legend()
axs[0].set_xticklabels(months, rotation=45)

# Plot for affected cases
axs[1].bar(months, predicted_affected_cases, color='blue', alpha=0.7, label='Affected Cases')
axs[1].set_ylabel('Affected Cases')
axs[1].set_title('Predicted Affected Dengue Cases for 2024')
axs[1].legend()
axs[1].set_xticklabels(months, rotation=45)

# Plot for death cases
axs[2].bar(months, predicted_death_cases, color='red', alpha=0.7, label='Death Cases')
axs[2].set_ylabel('Death Cases')
axs[2].set_title('Predicted Death Dengue Cases for 2024')
axs[2].legend()
axs[2].set_xticklabels(months, rotation=45)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_1940\3059675277.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_xticklabels(months, rotation=45)
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_1940\3059675277.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_xticklabels(months, rotation=45)
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_1940\3059675277.py:33: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[2].set_xticklabels(months, rotation=45)
